# %% [markdown]
# # Basic setup
#
# Here we will import the `pyspark` module and set up a `SparkContext` running on the local machine with one executor for every core on the local machine.

# %%
import pyspark
spark = pyspark.SparkContext("local[*]")

# %% [markdown]
# # Creating a resilient distributed dataset (RDD)
#
# One of the easiest ways to create a resilient distributed dataset is from a local collection, with the `parallelize` method on the `SparkContext` object.

# %%
numberRDD = spark.parallelize(range(1, 10000))

# %% [markdown]
# You can also create RDDs from files, S3 objects, and other external data sources.  See [the documentation](https://spark.apache.org/docs/latest/programming-guide.html#external-datasets) for more information.
#
# # Basic RDD transformations
#
# RDDs are _immutable_, so to transform a RDD, we create a new one.  RDDs are also _lazy_, so instead of transforming the elements when we create the new RDD, we store a reference to the original and the operation we'd need to apply to it to construct the transformed RDD.

# %%
# filter numberRDD, keeping only even numbers
evens = numberRDD.filter(lambda x: x % 2 == 0)

# produce an RDD by doubling every element in numberRDD
doubled = numberRDD.map(lambda x: x * 2)

# filter numberRDD, keeping only multiples of five
fives = numberRDD.filter(lambda x: x % 5 == 0)

# return an RDD of the elements in both evens and fives
tens = evens.intersection(fives)
sortedTens = tens.sortBy(lambda x: x)

# %% [markdown]
# You can see other RDD transformations in the [Spark documentation](https://spark.apache.org/docs/latest/programming-guide.html#transformations).
#
# # RDD actions
#
# Since RDDs are lazy and RDD transformations don't actually compute anything, we need some way to force Spark to actually schedule a computation.  RDD _actions_ are operations that schedule the graph of computations implied by an RDD and return a result to the main program.  Here are a few examples:

# %%
(evens.count(), doubled.count())
# Out:
# (4999, 9999)

# %%
# note that we may not get results in order!
tens.take(5)
# Out:
# [8320, 2080, 4160, 480, 8800]

# %%
# ...unless we sort
sortedTens.take(5)
# Out:
# [10, 20, 30, 40, 50]

# %%
# we can take a sample from an RDD (with or without replacement)
sortedTens.takeSample(False, 10)
# Out:
# [2570, 2910, 8620, 900, 870, 6390, 6270, 6700, 2610, 3330]

# %%
sortedTens.reduce(lambda x, y: max(x, y))
# Out:
# 9990

# %% [markdown]
# You can see some other RDD actions in the [Spark documentation](https://spark.apache.org/docs/latest/programming-guide.html#actions).
#
# # Structured query and data frames
#
# Spark also includes support for structured queries, including SQL and pandas- or R-like "data frame" operations through a query DSL.  In order to use this support (in Spark 1.x), you'll need to create a `SQLContext` object:

# %%
from pyspark.sql import SQLContext
sqlc = SQLContext(spark)

# %% [markdown]
# Let's see structured query in action by loading a [Parquet](http://parquet.apache.org/) file with some simplified [fedmsg](https://fedora-fedmsg.readthedocs.io/en/latest/) log messages.

# %%
df = sqlc.read.parquet("/msgs.parquet")
df.printSchema()
# Out:
# root
#  |-- category: string (nullable = true)
#  |-- i: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- msg: string (nullable = true)
#  |-- msg_id: string (nullable = true)
#  |-- source_name: string (nullable = true)
#  |-- source_version: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- topic: string (nullable = true)

# %% [markdown]
# We can use the data frame DSL to do RDBMS-style queries on these data, which is great for characterizing or exploring it.  Because these queries can execute in parallel or across multiple machines, aggregations can be _much_ faster in Spark than they are on a traditional RDBMS.
#
# It is simple to do basic aggregations, like this:

# %%
df.groupBy('category').count().orderBy('count', ascending=False).show()
# Out:
# +------------+-------+
# |    category|  count|
# +------------+-------+
# |    buildsys|3494565|
# |         git|  92611|
# |        copr|  76774|
# |       pkgdb|  43328|
# |       bodhi|  33624|
# |fedoratagger|  30835|
# |   fedbadges|  29494|
# |        wiki|  17609|
# |      askbot|  15278|
# |         fas|  13022|
# |  summershum|   6996|
# |        trac|   6496|
# |     compose|   5340|
# |        null|   5095|
# |     ansible|   4333|
# |      github|   4291|
# |      planet|   3926|
# |     meetbot|   3016|
# |      anitya|   1300|
# |         fmn|    817|
# +------------+-------+
# only showing top 20 rows

# %% [markdown]
# (This file isn't huge, but it's in the Docker image.)

# %%
df.count()
# Out:
# 3889881

# %% [markdown]
# We can use the `show` method to quickly inspect a few rows of a data frame (not just the results of a query).  This is often helpful to sanity-check a new data source.

# %%
df.show(10)
# Out:
# +------------+---+--------+--------------------+--------------------+-----------+--------------+--------------------+--------------------+
# |    category|  i|      id|                 msg|              msg_id|source_name|source_version|           timestamp|               topic|
# +------------+---+--------+--------------------+--------------------+-----------+--------------+--------------------+--------------------+
# |       bodhi|  1|       1|{"comment":{"anon...|                null| datanommer|             0|2012-10-08T17:38:...|org.fedoraproject...|
# |    buildsys|282|10000000|{"build_id":23690...|2014-bf43ca16-aa9...| datanommer|         0.6.4|2014-08-22T04:20:...|org.fedoraproject...|
# |    buildsys|283|10000001|{"build_id":23690...|2014-bd536558-253...| datanommer|         0.6.4|2014-08-22T04:20:...|org.fedoraproject...|
# |    buildsys|286|10000004|{"build_id":17994...|2014-46706d25-846...| datanommer|         0.6.4|2014-08-22T04:20:...|org.fedoraproject...|
# |        copr|133|10000017|{"build":28674,"c...|2014-b57ceaca-e0c...| datanommer|         0.6.4|2014-08-22T04:23:...|org.fedoraproject...|
# |    buildsys|  1|10000020|{"build_id":44896...|2014-f232706c-d09...| datanommer|         0.6.4|2014-08-22T04:23:...|org.fedoraproject...|
# |    buildsys|  1|10000021|{"instance":"ppc"...|2014-3460a6c6-30a...| datanommer|         0.6.4|2014-08-22T04:21:...|org.fedoraproject...|
# |        copr| 70|10000026|{"build":28675,"c...|2014-f9f97d0d-0d1...| datanommer|         0.6.4|2014-08-22T04:24:...|org.fedoraproject...|
# |fedoratagger|  1| 1000003|{"tag":{"dislike"...|                null| datanommer|         0.5.0|2013-09-08T20:14:...|org.fedoraproject...|
# |         git|  1|10000030|{"agent":"corsepi...|2014-264ffdac-a42...| datanommer|         0.6.4|2014-08-22T04:24:...|org.fedoraproject...|
# +------------+---+--------+--------------------+--------------------+-----------+--------------+--------------------+--------------------+
# only showing top 10 rows

# %% [markdown]
# # Data cleaning
#
# Uh oh!  It looks like the `msg` field of this data frame is JSON-encoded message structures instead of actual message structures.  While we'd _never_ see messy data in the real world, this really throws a wrench into our tutorial.  Let's fix that by asking Spark to infer a schema for the JSON fields.

# %%
msgRDD = df.select("msg").rdd.map(lambda x: x[0])
# structs = sqlc.jsonRDD(msgRDD)
# structs.printSchema()

# %% [markdown]
# You'll notice that the last two lines are commented out there, and with good reason.  You can uncomment them and run them, but only if you're patient and willing to scroll. You'll get a huge schema with objects that have one field for (as one example) every Fedora user who has ever participated in an IRC meeting! (Alternatively, [click here](https://gist.github.com/willb/ede22cdcd25b64e8cda952f927701d96) to see a rendered version of the inferred schema.)
#
# Spark can't infer a useful schema for these JSON records, because their schemas diverge and because of some of the unusual ways that `fedmsg` data uses JSON to encode maps.  While there are a few reasons for the schema divergence (see [a practical treatment](http://chapeau.freevariable.com/2014/10/fedmsg-and-spark.html) or a more [type-theoretic one](http://chapeau.freevariable.com/2014/11/algebraic-types.html)), in this case one problem is that different `fedmsg` messages use the `branches` field to refer to values with incompatible types.
#
# Fortunately, we can fix that with a pretty quick hack.  We'll just go through every record and retain only a few fields that we know are not going to give us grief.  (You'd probably want to do something more sophisticated in a real application.)  We'll use Spark's _user-defined function_ mechanism to achieve this.

# %%
import json

# define the fields we want to keep
interesting_fields = ['agent', 'author', 'copr', 'user', 'msg', 'meeting_topic', 'name', 'owner', 'package']

# describe the return type of our user-defined function
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
resultType = StructType([StructField(f, StringType(), nullable=True) for f in interesting_fields])

# this is the body of our first user-defined function, to restrict us to a subset of fields
def trimFieldImpl(js):
    try:
        d = json.loads(js)
        return [d.get(f) for f in interesting_fields]
    except:
        # return an empty struct if we fail to parse this message
        return [None] * len(interesting_fields)
    
from pyspark.sql.functions import udf

# register trimFieldImpl as a user-defined function
trimFields = udf(trimFieldImpl, resultType)

trimmedDF = df.withColumn("msg", trimFields("msg"))

# %%
trimmedDF.printSchema()
# Out:
# root
#  |-- category: string (nullable = true)
#  |-- i: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- msg: struct (nullable = true)
#  |    |-- agent: string (nullable = true)
#  |    |-- author: string (nullable = true)
#  |    |-- copr: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |    |-- msg: string (nullable = true)
#  |    |-- meeting_topic: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- owner: string (nullable = true)
#  |    |-- package: string (nullable = true)
#  |-- msg_id: string (nullable = true)
#  |-- source_name: string (nullable = true)
#  |-- source_version: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- topic: string (nullable = true)

# %% [markdown]
# Data frames are a great way to explore structured data, but you can also train models against them (either by converting to RDDs and using [MLlib](https://spark.apache.org/docs/latest/mllib-guide.html) or by using [ML Pipelines](https://spark.apache.org/docs/latest/ml-guide.html) to define learning pipelines directly on data frames).
#
# Let's extract bug and update comments from our `fedmsg` data and use those to train a word2vec model.

# %%
def getComments(js):
    try:
        d = json.loads(js)
        cs = d.get('comment', []) + d.get('update', {}).get('comments', [])
        notes = 'notes' in d and [d['notes']] or []
        return [c['text'] for c in cs if c.has_key('text')] + []
    except:
        return []

commentsRDD = msgRDD.flatMap(lambda js: getComments(js))

# turn comments into sequences of words.  don't bother stripping punctuation or stemming #yolo
wordSeqs = commentsRDD.map(lambda s: s.split())

# %%
# actually train a model

from pyspark.mllib.feature import Word2Vec

w2v = Word2Vec()
model = w2v.fit(wordSeqs)

# find synonyms for a given word
synonyms = model.findSynonyms('works', 5)

for word, distance in synonyms:
    print("{}: {}".format(word, distance))
# Out:
# Works: 2.20867294376
# fine: 2.08998290367
# good: 1.8792983991
# me: 1.86386831913
# work: 1.85234287117

# %%
# see what words are in the model

model.getVectors().keys()
# Out:
# [u'breaks',
#  u'(fedora)',
#  u'yaneti.',
#  u'immanetize.',
#  u'hpejakle.',
#  u'submitted',
#  u'plugin',
#  u'looks',
#  u'kkeithle.',
#  u'tgl.',
#  u'Error:',
#  u'jdunn.',
#  u'nalin',
#  u'used',
#  u'automatic',
#  u'mystro256.',
#  u'oget.',
#  u'frafra.',
#  u'Still',
#  u'Please',
#  u'oliver.',
#  u'stahnma.',
#  u'sddm-0.2.0-0.19.20130914git50ca5b20.fc20.',
#  u'unpushed',
#  u'pavlix.',
#  u'mitr.',
#  u'emaldonado',
#  u'goeran.',
#  u'jsteffan.',
#  u'mmilata.',
#  u'kumarpraveen.',
#  u'davidz.',
#  u'Does',
#  u"it's",
#  u'goldmann.',
#  u'rjones',
#  u'canl-c',
#  u'application',
#  u'please',
#  u'fpokorny.',
#  u'nodejs-form-data-0.1.0-1.el6,',
#  u'desktop',
#  u'noarch.',
#  u'number',
#  u'mluscon.',
#  u'able',
#  u"that's",
#  u'devrim.',
#  u'failure',
#  u'roma.',
#  u'jvcelak.',
#  u'for',
#  u'iankent.',
#  u'tingping.',
#  u'jfsaucier.',
#  u'mschwendt',
#  u'rfenkhuber.',
#  u'adrian.',
#  u'network',
#  u'averi.',
#  u'scottt.',
#  u'anishpatil.',
#  u'functionality',
#  u'logic.',
#  u'support',
#  u'<module>',
#  u'paller.',
#  u'buildroot',
#  u'post',
#  u'works.',
#  u'test',
#  u'further',
#  u'nodejs-rimraf-2.2.2-1.el6,',
#  u'works',
#  u'ipvsadm',
#  u'working',
#  u'dependency.',
#  u'nphilipp',
#  u'cqrlog-1.5.8-2.fc18.',
#  u'reach',
#  u'package',
#  u'airlied.',
#  u'due',
#  u'any',
#  u'kernel',
#  u'ARM',
#  u'jhernand.',
#  u'mfabian.',
#  u'module',
#  u'production',
#  u'rohara.',
#  u'jchaloup.',
#  u'KF5',
#  u'successfully',
#  u'Thanks.',
#  u'For',
#  u'arg.',
#  u'crash.',
#  u'niveusluna.',
#  u'name',
#  u'philipp.',
#  u'this',
#  u"haven't",
#  u'martinkg.',
#  u'(source',
#  u'delete.',
#  u'instead',
#  u'in',
#  u'move',
#  u'domcleal.',
#  u'pschiffe.',
#  u'changes.',
#  u'smoke',
#  u'slaanesh.',
#  u'provided',
#  u'With',
#  u'strobert.',
#  u'leveldb-1.7.0-2.fc18.',
#  u'erlang-riak_core-1.3.0-1.fc18.',
#  u'based',
#  u'ignatenkobrain',
#  u'berrange.',
#  u'sagarun.',
#  u'madko.',
#  u'have',
#  u'needed',
#  u's4504kr',
#  u'your',
#  u'reported',
#  u'once',
#  u'bonzini.',
#  u'again.',
#  u'mstevens.',
#  u'are',
#  u'is',
#  u'gerd.',
#  u'dependency',
#  u'source',
#  u'denisarnaud.',
#  u'far.',
#  u'caused',
#  u'remi.',
#  u'why',
#  u'wait',
#  u'Transaction',
#  u'jakub.',
#  u'kdaniel.',
#  u'xavierb.',
#  u'Personal',
#  u'hvad.',
#  u'*',
#  u'19',
#  u'too',
#  u'nodejs-request-2.25.0-1.el6.noarch',
#  u'feature',
#  u'achernya.',
#  u'FreeIPA',
#  u'built',
#  u'nucleo.',
#  u'repository',
#  u'pcpa.',
#  u"It's",
#  u'<=',
#  u'psss.',
#  u'makes',
#  u'jorton',
#  u'verdurin.',
#  u'dgoodwin.',
#  u'replace',
#  u'gsgatlin.',
#  u'simo.',
#  u'GNOME.',
#  u'show',
#  u'Testing.',
#  u'pali.',
#  u'BZ',
#  u'lennart.',
#  u'seen',
#  u'jjames',
#  u'likely',
#  u'request',
#  u'rmeggins.',
#  u'pwu.',
#  u'server',
#  u'said',
#  u'pspacek.',
#  u'fab.',
#  u'rjones.',
#  u'hard',
#  u'4',
#  u'bsjones.',
#  u'try',
#  u'already',
#  u'dledford',
#  u'All',
#  u'break',
#  u'path',
#  u'vascom.',
#  u'erlang-riak_control-1.3.2-1.fc19.',
#  u'dtimms.',
#  u'soon',
#  u'got',
#  u'dionysos.',
#  u'swagiaal.',
#  u'using',
#  u'[root@localhost',
#  u'am',
#  u'marionline.',
#  u'system',
#  u'real',
#  u'luya.',
#  u'gholms',
#  u'jmarrero.',
#  u'commit',
#  u'aglitke.',
#  u'ellert.',
#  u'than',
#  u'mgieseki.',
#  u'update,',
#  u"isn't",
#  u'build.',
#  u'obsoleted',
#  u"didn't",
#  u'Package:',
#  u'kalev.',
#  u'testing,',
#  u'rocha.',
#  u'kad.',
#  u'included',
#  u'backtrace',
#  u'ivanromanov.',
#  u'tsmetana.',
#  u'(I',
#  u'report.',
#  u'Yes,',
#  u'bubeck.',
#  u'sagitter.',
#  u'devos.',
#  u'want',
#  u'marcindulak.',
#  u'kg4sgp.',
#  u'epoch',
#  u'--skip-broken',
#  u'noticed',
#  u'jhrozek.',
#  u'corruption',
#  u'jistone.',
#  u'vpodzime.',
#  u'Basic',
#  u'time.',
#  u'nodejs-cryptiles-0.2.2-1.el6,',
#  u'(results',
#  u'patches',
#  u'Using',
#  u'pmachata.',
#  u'fedora',
#  u'krege.',
#  u'AutoQA:',
#  u'snavin.',
#  u'hguemar.',
#  u'kkofler.',
#  u'exist',
#  u'problems.',
#  u'sbergmann.',
#  u'isimluk.',
#  u'mmckinst.',
#  u'dougsland.',
#  u'This',
#  u'After',
#  u'minipro-0-6.20140902git1b451ae.fc20.',
#  u'uglify-js-2.4.13-3.el6.',
#  u'.',
#  u'bronhaim.',
#  u'In',
#  u'error:',
#  u'mhlavink.',
#  u'but',
#  u'state',
#  u'whether',
#  u'jamielinux',
#  u'working.',
#  u'regressions',
#  u'sure',
#  u'released',
#  u'solve',
#  u'wrong',
#  u'ignatenkobrain.',
#  u'i686.',
#  u'mclasen.',
#  u'root',
#  u'ellert',
#  u'works!',
#  u'security',
#  u'kwizart.',
#  u'erlang-riak_control-1.3.0-1.fc18.',
#  u'correctly',
#  u'maxamillion.',
#  u'dsd.',
#  u'besser82',
#  u'--->',
#  u'jkaluza.',
#  u'unable',
#  u'wzzrd.',
#  u'master',
#  u'shared',
#  u'twaugh.',
#  u'nodejs-bindings-1.1.1-1.el6,',
#  u'jjames.',
#  u'spend',
#  u'toshio.',
#  u'what',
#  u'dep',
#  u'different',
#  u'would',
#  u'erlang-riak_api-1.3.0-1.fc18.',
#  u'causes',
#  u'fche.',
#  u'kushal.',
#  u'(and',
#  u'usage.',
#  u'tuanta.',
#  u'jorton.',
#  u'another',
#  u'checked',
#  u'Update',
#  u'timfenn.',
#  u'nphilipp.',
#  u'msivak.',
#  u'recent',
#  u'too.',
#  u'LGTM',
#  u'sharkcz.',
#  u'PASSED',
#  u'Updated',
#  u'image',
#  u'line',
#  u'boot',
#  u'dmalcolm.',
#  u'if',
#  u'jirka.',
#  u'good',
#  u'vicodan.',
#  u'pipelight-selinux-0.2.0-1.fc20.',
#  u'bojan.',
#  u'selinux',
#  u'browser',
#  u'You',
#  u'running',
#  u'chkr.',
#  u'problem',
#  u'Taskotron:',
#  u'dennisvd.',
#  u'Good',
#  u'usage',
#  u'that.',
#  u'llagendijk.',
#  u'elmarco.',
#  u'own',
#  u'conflict',
#  u'here,',
#  u'resource-agents',
#  u'Error',
#  u'up',
#  u'lgtm',
#  u'lbazan',
#  u'=',
#  u'going',
#  u'lmacken',
#  u'tgraf.',
#  u'nodejs-sha-1.2.1-1.el6,',
#  u'EPEL',
#  u'uses',
#  u'depcheck',
#  u'mjg.',
#  u'so',
#  u'jsorensen.',
#  u'3.12',
#  u'Why',
#  u'expected',
#  u'comzeradd.',
#  u'miminar',
#  u'jujens.',
#  u'fale.',
#  u'per',
#  u'broke',
#  u'must',
#  u'nodejs-npm-registry-client-0.2.27-2.el6,',
#  u'somlo.',
#  u'psavelye.',
#  u'obsoletes',
#  u'normal',
#  u'Sorry',
#  u'dcantrel.',
#  u'fmuellner.',
#  u'keep',
#  u'michich.',
#  u'do',
#  u'spot.',
#  u'all',
#  u'-Va',
#  u'branto.',
#  u'mso.',
#  u'simonm.',
#  u'(epel-testing)',
#  u'mmagr.',
#  u'i686',
#  u'crash',
#  u"I've",
#  u'version.',
#  u'stable.',
#  u'kkofler',
#  u'avesh.',
#  u'scriptlet',
#  u'confirmed',
#  u'tflink.',
#  u'tmraz.',
#  u'whot.',
#  u'ran',
#  u'<',
#  u'bpostle.',
#  u'normunds.',
#  u'thanks',
#  u'kevin.',
#  u'timn.',
#  u'nalimilan.',
#  u'previous',
#  u'Tested',
#  u'ankursinha.',
#  u'nmav.',
#  u'F20',
#  u'had',
#  u'rebuild',
#  u'package:',
#  u'correct',
#  u'tmz.',
#  u'ebaron.',
#  u'thanks.',
#  u'crobinso.',
#  u'present',
#  u'f18',
#  u'node-gyp-0.10.6-2.el6,',
#  u'cwickert.',
#  u'peter',
#  u'run',
#  u'look',
#  u'cleech.',
#  u'lfield.',
#  u'thl.',
#  u'submitter,',
#  u'bellet.',
#  u'users',
#  u'amluto.',
#  u'mbooth.',
#  u'mharmsen.',
#  u'breakage',
#  u'Dependency:',
#  u'result',
#  u'beckerde.',
#  u'audio',
#  u'wwoods.',
#  u'Eclipse',
#  u'Could',
#  u'sergiomb.',
#  u'vpv.',
#  u'package.',
#  u'ovasik.',
#  u'set',
#  u'georgiou.',
#  u'nodejs-request-2.25.0-1.el6,',
#  u'brummbq.',
#  u'rmattes',
#  u"I'm",
#  u'before',
#  u'eponyme.',
#  u'crashes',
#  u'dmlb2000.',
#  u'ttorcz.',
#  u'gnucash-2.4.15-2.el6.',
#  u'push',
#  u'jsafrane',
#  u'van.',
#  u'aalvarez.',
#  u'manually',
#  u'fcami.',
#  u'just',
#  u'override',
#  u'else',
#  u'xqueralt.',
#  u'fails',
#  u'sundaram.',
#  u'mhlavink',
#  u'echevemaster.',
#  u'ssahani.',
#  u'bioinfornatics.',
#  u'it',
#  u'case.',
#  u'siddharths.',
#  u'opuk.',
#  u'noted',
#  u'dfateyev.',
#  u'lkundrak.',
#  u'nodejs-fstream-0.1.24-1.el6,',
#  u'ausil.',
#  u'ppisar',
#  u'runs',
#  u'noted.',
#  u'Removing:',
#  u'fix',
#  u'me,',
#  u'two',
#  u'local',
#  u'failed',
#  u'fix.',
#  u'callkalpa.',
#  u'tests',
#  u'jkeating.',
#  u'dchen.',
#  u'F18.',
#  u'awood.',
#  u'a',
#  u'And',
#  u'Updating',
#  u'rombobeorn.',
#  u'nhosoi.',
#  u'mstuchli.',
#  u'encountered',
#  u'->',
#  u'rrankin.',
#  u'thm',
#  u'Heimdal',
#  u'newer',
#  u'dscott.',
#  u'grenier.',
#  u'sailer.',
#  u'terminalmage.',
#  u'negative',
#  u'nss-util',
#  u'smani.',
#  u'cbb.',
#  u'ralph.',
#  u'hhorak',
#  u'frankcrawford.',
#  u'Removed',
#  u'marx.',
#  u'honzaf.',
#  u'maintainer',
#  u'orion.',
#  u'described',
#  u'hannes',
#  u'filiperosset.',
#  u'plautrba.',
#  u'Thanks',
#  u'16',
#  u'seeing',
#  u'prajnoha.',
#  u'avagin.',
#  u'cicku.',
#  u'msrb.',
#  u'nodejs-glob-3.2.6-1.el6,',
#  u'though',
#  u'issue.',
#  u'bad',
#  u'boots',
#  u'>=',
#  u'nucleo',
#  u'daemon',
#  u'as',
#  u'build',
#  u'jsmith.',
#  u'ndim.',
#  u'marked',
#  u'jpeeler.',
#  u'jstribny.',
#  u'ausil',
#  u'repository.',
#  u'buc.',
#  u'holcapek.',
#  u'alexlan.',
#  u'because',
#  u'jamatos.',
#  u'stevej.',
#  u'afsilva.',
#  u'vakwetu.',
#  u'well',
#  u'bjohnson.',
#  u'load',
#  u'mef.',
#  u'faxguy.',
#  u'5',
#  u'has',
#  u'currently',
#  u'gd.',
#  u'slaanesh',
#  u'mrunge.',
#  u'josef.',
#  u'Fedora',
#  u'stefanb.',
#  u'stransky.',
#  u'okay',
#  u'nodejs-mute-stream-0.0.4-1.el6,',
#  u'jsafrane.',
#  u'adev.',
#  u'We',
#  u'mkrizek.',
#  u'steved.',
#  u'wfp.',
#  u'-qf',
#  u'cfu.',
#  u'changes',
#  u'zeenix.',
#  u'|',
#  u'remi',
#  u'libmarblewidget.so.14()(64bit)',
#  u'mgrepl',
#  u'mattia.',
#  u'removed',
#  u'mcepl.',
#  u'corsepiu.',
#  u'smilner.',
#  u'jplesnik.',
#  u'nodejs-tar-0.1.18-1.el6,',
#  u'conflicts',
#  u'errors',
#  u'old',
#  u'shakthimaan.',
#  u'quite',
#  u'i386.',
#  u'codeblock.',
#  u'hhorak.',
#  u'additional',
#  u'yet',
#  u'jcholast.',
#  u'frixxon.',
#  u'cdamian.',
#  u'leamas.',
#  u'dnf',
#  u'Can',
#  u'rm',
#  u'fenris02.',
#  u'particular',
#  u'soname',
#  u'or',
#  u'seems',
#  u'above',
#  u'peter.',
#  u'lbazan.',
#  u'submit',
#  u'fixed,',
#  u'theinric.',
#  u'jwrdegoede.',
#  u'ueno.',
#  u'amcnabb.',
#  u'sparks.',
#  u'maci.',
#  u'kenjiro.',
#  u'jcwillia.',
#  u'There',
#  u'jsbackus.',
#  u'makowski.',
#  u'jpo.',
#  u'sophiekovalevsky.',
#  u'monnerat.',
#  u'fine,',
#  u'bmarzins.',
#  u'Processing',
#  u'+1',
#  u'sgallagh.',
#  u'tc01.',
#  u'GNOME',
#  u'laptop',
#  u'command',
#  u'spotted',
#  u'segfault',
#  u'such',
#  u'bojan',
#  u'detected.',
#  u'zultron.',
#  u'mayorga.',
#  u'reaches',
#  u'=)',
#  u'critical',
#  u'they',
#  u'jdob.',
#  u'juergh.',
#  u'grep',
#  u'trying',
#  u'problems',
#  u'following',
#  u'provide',
#  u'far',
#  u'jskarvad.',
#  u'exactly',
#  u'nodejs-semver-2.1.0-1.el6,',
#  u'xhorak.',
#  u'x86_64',
#  u'jpopelka.',
#  u'21',
#  u'gil.',
#  u'way',
#  u'hobbes1069.',
#  u'dridi.',
#  u'last',
#  u'bcl.',
#  u'till.',
#  u'sumwars-0.5.6-12.fc19,',
#  u"can't",
#  u'minh.',
#  u'open',
#  u'kzak.',
#  u'pbrady.',
#  u'building',
#  u'mojavelinux.',
#  u'service',
#  u'daily',
#  u'pavlix',
#  u'rrati.',
#  u'I',
#  u'patches.',
#  u'packages.',
#  u'tommi.',
#  u"don't",
#  u'jgrulich.',
#  u'i',
#  u'depending',
#  u'until',
#  u'davidcl.',
#  u'uglify-js-2.4.13-2.el6.',
#  u'fbl.',
#  u'testing',
#  u'avoid',
#  u'work',
#  u'mariobl.',
#  u'melmorabity.',
#  u'Should',
#  u'changed',
#  u'icons',
#  u'dvratil',
#  u'files',
#  u'thanks!',
#  u"I'd",
#  u'it,',
#  u'davem.',
#  u'ooprala.',
#  u'athmane.',
#  u'leigh123linux.',
#  u'that',
#  u'dmaphy.',
#  u'out',
#  u'stevetraylen.',
#  u'jcapik.',
#  u'epienbro',
#  u'ndipanov.',
#  u'nodejs-npmconf-0.1.2-1.el6,',
#  u'push.',
#  u'volter.',
#  u'F19',
#  u'jtulak.',
#  u'nb',
#  u'cannot',
#  u'(updates-testing)',
#  u'rspanton.',
#  u'No',
#  u'well,',
#  u'jforbes.',
#  u'Requires:',
#  u'pjones.',
#  u'LAMP',
#  u'trondham.',
#  u'teuf.',
#  u'robert',
#  u'eseyman.',
#  u'pushed.',
#  u'to',
#  u'work.',
#  u'Since',
#  u'myoung.',
#  u'me!',
#  u'ktdreyer.',
#  u'now.',
#  u'getting',
#  u'epienbro.',
#  u'atkac.',
#  u'jankratochvil.',
#  u'issue',
#  u'update:',
#  u'cheeselee.',
#  u'least',
#  u'ruben.',
#  u'lvrabec.',
#  u'deji.',
#  u'metainfo',
#  u'now',
#  u'works,',
#  u'code',
#  u'-',
#  u'sddm-0.2.0-0.16.20130914git50ca5b20.fc20.',
#  u'oron.',
#  u'rdieter.',
#  u'lkundrak',
#  u'you',
#  u'part,',
#  u'solves',
#  u'ahs3.',
#  u'problem.',
#  u'wilqu.',
#  u'matt.',
#  u'yum',
#  u'know',
#  u'casual',
#  u'found.',
#  u'erlang-riak_sysmon-1.1.3-1.fc18.',
#  u'downgrade',
#  u'vcrhonek.',
#  u'OK',
#  u'mlichvar.',
#  u'dvratil.',
#  u'probably',
#  u'terjeros.',
#  u'did',
#  u'vondruch.',
#  u'mpaladin.',
#  u'small',
#  u'around',
#  u'File',
#  u'pipelight-selinux-0.2.0-2.fc20.',
#  u'minipro-0-4.20140902git1b451ae.fc20.',
#  u'@@',
#  u'causing',
#  u'like,',
#  u'hubbitus.',
#  u',',
#  u'http://autoqa.fedoraproject.org/report/1bkfv',
#  u'herlo.',
#  u'firemanxbr.',
#  u'3.14',
#  u'here.',
#  u'stefansf.',
#  u'richzendy.',
#  u'bkabrda.',
#  u'most',
#  u'here',
#  u'these',
#  u'notting.',
#  u'erack.',
#  u'kevin',
#  u'karlik.',
#  u'bodhi',
#  u'sdodson.',
#  u'thofmann.',
#  u'help',
#  u'was',
#  u'reproduce',
#  u'abeche.',
#  u'texlive',
#  u'pghmcfc.',
#  u'version',
#  u'mbriza.',
#  u'yet.',
#  u'there',
#  u'jfilak',
#  u'mycae.',
#  u'musuruan.',
#  u'found',
#  u'change',
#  u'jamesnz.',
#  u'systemd',
#  u'6',
#  u'greenscientist.',
#  u'snirkel.',
#  u'feedback',
#  u'something',
#  u'nss-3.14-5.fc18.',
#  u'kubo.',
#  u'tradej.',
#  u'block',
#  u'git',
#  u'nothing',
#  u'raveit65.',
#  u'scop.',
#  u'mohammedisam.',
#  u'galileo.',
#  u'danw.',
#  u'at',
#  u'1',
#  u'depends',
#  u'zbyszek.',
#  u'updates-testing',
#  u'dbruno.',
#  u'consisting',
#  u'been',
#  u'rebuilding',
#  u'The',
#  u'rtcm.',
#  u'0ad-0.0.13-2.fc19,',
#  u'tmlcoch.',
#  u'older',
#  u'jlieskov.',
#  u'added',
#  u'tagoh.',
#  u'rathann.',
#  u'go',
#  u'jeckersb.',
#  u'import',
#  u'koji',
#  u'thozza',
#  u'fixed.',
#  u'mjw.',
#  u':-)',
#  u'bbbush.',
#  u'kimheino.',
#  u'vmukhame.',
#  u'djuran.',
#  u'ingvar.',
#  u'nodejs-hawk-1.0.0-1.el6,',
#  u'halfie.',
#  u'over',
#  u'yalgaer.',
#  u'also',
#  u'stingray.',
#  u'Bug',
#  u'issues.',
#  u'need',
#  u'can',
#  u'--daemon',
#  u'mcpierce.',
#  u'on',
#  u'one.',
#  u'17',
#  u'giallu.',
#  u'dwalsh.',
#  u'jpopelka',
#  u'jgu.',
#  u'eharney.',
#  u'petersen',
#  u'being',
#  u'pnemade',
#  u'vondruch',
#  u'mpreisle.',
#  u'dhowells.',
#  u'brouhaha.',
#  u'yograterol.',
#  u'related',
#  u'same',
#  u'rstrode.',
#  u'rolffokkens.',
#  u"'yum",
#  u'installation',
#  u'updates',
#  u'tstclair.',
#  u'happy',
#  u'ok.',
#  u'dtardon.',
#  u'pwouters.',
#  u'OpenSSL',
#  u'jlayton.',
#  u'nodejs-request-2.25.0-2.el6.',
#  u'fixing',
#  u'remove',
#  u'updated',
#  u'check',
#  u'cottsay.',
#  u'click',
#  u'how',
#  u'my',
#  u'-->',
#  u'Is',
#  u'nodejs-read-package-json-1.1.1-1.el6,',
#  u'pingou.',
#  u'appears',
#  u'14',
#  u'Fixes',
#  u'detected',
#  u'nbecker.',
#  u'error',
#  u'Installed',
#  u'Thank',
#  u'bug.',
#  u'after',
#  u'affected',
#  u'jcp.',
#  u'dcbw.',
#  u'thm.',
#  u'sergiopr.',
#  u'besser82.',
#  u'fujiwara.',
#  u'paragn.',
#  u'live',
#  u'take',
#  u'kenhys.',
#  u'lsm5.',
#  u'pfrields.',
#  u'correctly.',
#  u'jgrulich',
#  u'00:00',
#  u'jsynacek.',
#  u'good,',
#  u"AutoQA's",
#  u'ravindrakumar.',
#  u'ricardo.',
#  u'issues',
#  ...]
